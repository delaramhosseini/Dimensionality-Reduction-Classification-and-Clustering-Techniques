# %%
import pandas
data = pandas.read_csv('first_clustering_dataset.csv')
data.info
# Out:
# <bound method DataFrame.info of      -0.125390783788733  -1.26882910106011
# 0              0.062522           1.278778
# 1             -0.048762           0.200549
# 2              0.105585          -0.496629
# 3              0.011886          -0.739317
# 4             -0.006710          -0.710735
# ..                  ...                ...
# 394            0.248226          -1.088287
# 395            0.205768          -0.421411
# 396            0.269167           0.695011
# 397            0.211597           0.977275
# 398            0.261713          -0.993928
#
# [399 rows x 2 columns]>

# %%
fig, ax = plt.subplots(1, 3, gridspec_kw={'wspace': 0.3}, figsize=(15,5))

for i in range(3):
    km = KMeans(n_clusters = 3, init='random', n_init=1, random_state=i)
    km.fit(data)
    ax[i].scatter(x= X.iloc[:, 0], y=X.iloc[:, 1], c= km.labels_);

# %%
fig, ax = plt.subplots(1, 3, gridspec_kw={'wspace': 0.3}, figsize=(15,5))

for i in range(3):
    km = KMeans(n_clusters = 3, init='random', n_init=1, random_state=i)
    km.fit(data)
    ax[i].scatter(x= X.iloc[:, 0], y=X.iloc[:, 1], c= km.labels_)

    ax[i].set_title(f"Inertia = {round(km.inertia_, 2)}");

# %%
wcss = [] 

for i in range(2,200):
    km = KMeans(n_clusters= i)
    km.fit(data)
    wcss.append(km.inertia_)
    
plt.plot(range(2,200), wcss, 'og-')
plt.annotate('Elbow', xy=(5, 50), xytext=(6, 10), arrowprops=dict(facecolor='green', shrink=0.05))
plt.xlabel("K")
plt.ylabel("Inertia");

# %%
data2 = pandas.read_csv('second_clustering_dataset.csv')
data.info
# Out:
# <bound method DataFrame.info of      -0.125390783788733  -1.26882910106011
# 0              0.062522           1.278778
# 1             -0.048762           0.200549
# 2              0.105585          -0.496629
# 3              0.011886          -0.739317
# 4             -0.006710          -0.710735
# ..                  ...                ...
# 394            0.248226          -1.088287
# 395            0.205768          -0.421411
# 396            0.269167           0.695011
# 397            0.211597           0.977275
# 398            0.261713          -0.993928
#
# [399 rows x 2 columns]>

# %%
fig, ax = plt.subplots(1, 3, gridspec_kw={'wspace': 0.3}, figsize=(15,5))

for i in range(3):
    km = KMeans(n_clusters = 3, init='random', n_init=1, random_state=i)
    km.fit(data2)
    ax[i].scatter(x= X.iloc[:, 0], y=X.iloc[:, 1], c= km.labels_);

# %%
fig, ax = plt.subplots(1, 3, gridspec_kw={'wspace': 0.3}, figsize=(15,5))

for i in range(3):
    km = KMeans(n_clusters = 3, init='random', n_init=1, random_state=i)
    km.fit(data2)
    ax[i].scatter(x= X.iloc[:, 0], y=X.iloc[:, 1], c= km.labels_)

    ax[i].set_title(f"Inertia = {round(km.inertia_, 2)}");

# %%
wcss = [] 

for i in range(2,200):
    km = KMeans(n_clusters= i)
    km.fit(data2)
    wcss.append(km.inertia_)
    
plt.plot(range(2,200), wcss, 'og-')
plt.annotate('Elbow', xy=(5, 50), xytext=(6, 10), arrowprops=dict(facecolor='green', shrink=0.05))
plt.xlabel("K")
plt.ylabel("Inertia");

# %%
data3 = pandas.read_csv('third_clustering_dataset.csv')
data.info
# Out:
# <bound method DataFrame.info of      -0.125390783788733  -1.26882910106011
# 0              0.062522           1.278778
# 1             -0.048762           0.200549
# 2              0.105585          -0.496629
# 3              0.011886          -0.739317
# 4             -0.006710          -0.710735
# ..                  ...                ...
# 394            0.248226          -1.088287
# 395            0.205768          -0.421411
# 396            0.269167           0.695011
# 397            0.211597           0.977275
# 398            0.261713          -0.993928
#
# [399 rows x 2 columns]>

# %%
fig, ax = plt.subplots(1, 3, gridspec_kw={'wspace': 0.3}, figsize=(15,5))

for i in range(3):
    km = KMeans(n_clusters = 3, init='random', n_init=1, random_state=i)
    km.fit(data3)
    ax[i].scatter(x= X.iloc[:, 0], y=X.iloc[:, 1], c= km.labels_);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4238             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4239                 colors = mcolors.to_rgba_array(c)
#    4240             except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py in <listcomp>(.0)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
# ...

# %%
fig, ax = plt.subplots(1, 3, gridspec_kw={'wspace': 0.3}, figsize=(15,5))

for i in range(3):
    km = KMeans(n_clusters = 3, init='random', n_init=1, random_state=i)
    km.fit(data3)
    ax[i].scatter(x= X.iloc[:, 0], y=X.iloc[:, 1], c= km.labels_)

    ax[i].set_title(f"Inertia = {round(km.inertia_, 2)}");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4238             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4239                 colors = mcolors.to_rgba_array(c)
#    4240             except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py in <listcomp>(.0)
#     339     else:
# --> 340         return np.array([to_rgba(cc, alpha) for cc in c])
#     341
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
# ...

# %%
wcss = [] 

for i in range(2,200):
    km = KMeans(n_clusters= i)
    km.fit(data3)
    wcss.append(km.inertia_)
    
plt.plot(range(2,200), wcss, 'og-')
plt.annotate('Elbow', xy=(5, 50), xytext=(6, 10), arrowprops=dict(facecolor='green', shrink=0.05))
plt.xlabel("K")
plt.ylabel("Inertia");
